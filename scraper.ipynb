# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #2: Adquisición de textos
# `Fecha de entrega: Agosto 29, 2020. (Antes del inicio de la próxima clase).`

# %% [markdown]
# # Punto 1:
#
# - Descomprimir el archivo `.zip` de los poemas
# - Leer cada uno de sus archivos
# - Responder: ¿Cuál archivo tiene el mayor número de palabras?

# %% [markdown]
# # Punto 2:
#
# - Hacer Web Scraping de 10 biografías en Wikipedia (en búcle)
# - Obtener el **encabezado** de cada biografía
# - Obtener todos los **contenidos** y **etiquetas de título** asociados a los **links** del primer párrafo

# %% [markdown]
# # Solución

# %% [markdown]
# ## 🛑 Punto 1

# %%
import os
import shutil
import operator
import urllib.request
import bs4 as bs
from zipfile import ZipFile

# %% [markdown]
# ### 🤖 Funcion para descomprimir .zip

# %%
def unzip_file(zip_file, target_folder):
    """ Descomprime el cotenido de [zip_file] en la carpeta [target_folder]
        Devuelve la ruta final del contenido. """
    try:
        with ZipFile(zip_file) as archivo: 
            archivo.extractall(target_folder)
            shutil.rmtree(target_folder+'/__MACOSX')
        return target_folder + '/' + zip_file.replace('.zip','/') 
    except Exception as e:
        print('Error descomprimiendo el archivo [{}] Mensaje: {}'.format(zip_file, str(e)))
        return None

# %% [markdown]
# ### 🤖 Función para obtener los nombres de archivos presentes en una ruta dada

# %%
def get_file_names_in_path(path):
    """ Devuelve una lista con los nombres de archivos en la ruta [path] """
    filenames = []
    try:
        for raiz, dirs, archivos in os.walk(path):
            for archivo in archivos:
                filenames.append(path+archivo)
        return filenames
    except Exception as e:
        print('Error leyendo los archivo en [{}] Mensaje: {}'.format(path, str(e)))
    return None

# %% [markdown]
# ### 🤖 Función para leer archivo y contar palabras en cada uno

# %%
def read_file_and_count_words(file_list):
    """ Devuelve una lista ordeneda de tuplas con el nombre del archivo y la cantidad de palabras que contiene. """
    word_counter = {}
    for file in file_list:
        with open(file) as archivo: 
            data = archivo.read()
            word_counter[file] = len(data.split())
    sorted_word_counter = sorted(word_counter.items(), key=operator.itemgetter(1), reverse=True)
    return list(sorted_word_counter)

# %% [markdown]
# ### ⚙️ Proceso

# %% [markdown]
# ### 🤔 ¿Cuál archivo tiene el mayor número de palabras?

# %%
unzip = unzip_file('poemas.zip', 'unzip')

if unzip:
    files = get_file_names_in_path(unzip)
    if files:
        result = read_file_and_count_words(files)
        print("RTA: El archivo que más contiene palabras es [{}] con [{}] palabras.\n\n".format(result[0][0], result[0][1]))
# Out:
# RTA: El archivo que más contiene palabras es [unzip/poemas/Si╠ündrome (Mario Benedetti).txt] con [53] palabras.

# %% [markdown]
# ## 🛑 Punto 2

# %% [markdown]
# ### 🤖 Función para obtener el html en soup

# %%
def get_soup(link):
    """ Hacer petición GET a una URL dada y devolver el html como soup """
    response = urllib.request.urlopen(link)
    source = response.read() 
    response.close()
    soup = bs.BeautifulSoup(source,'html.parser')
    return soup

# %% [markdown]
# ### 🤖 Función que obtiene los elementos h1, p, a, title

# %%
def call_wiki(link):
    """ Obtiene e imprime los datos de interes que se encuentran en la eqtiquetas. """
    soup = get_soup(link)

    print("="*100)
    print("• \033[1mUrl:\033[0m\n\t {}".format(link))
    print('• \033[1mEncabezado:\033[0m \n\t {}'.format(soup.find('h1', attrs={'id':'firstHeading'}).text))

    tags_a = soup.find('p').find_all('a')
    if len(tags_a) == 0:
        tags_a = soup.find_all('p')[1].find_all('a')
    
    if len(tags_a) > 0:
        print('• \033[1mLinks 1er parrafo:\033[0m')
        for tag_a in tags_a:
            print('\tContenido => {}'.format(tag_a.text))
            print('\tTitulo => {} \n'.format(tag_a.get('title')))
    else:
        print('El primer párrafo no contiene links.')

# %% [markdown]
# ### 🤖 Función que extrae y construye los links para hacer scraping desde otra web

# %%
def build_link_to_scraping(main_link, base_url_wiki):
    """ Extrae nombres de personas desde [main_link] y genera urls con base en la url [base_url_wiki] """
    soup_best_programmers = get_soup(main_link)
    li_programmer_names = soup_best_programmers.find(class_="list").find_all("li")
    links_to_scraping = []

    for programmer_name in li_programmer_names:
        full_name = programmer_name.text.split()
        links_to_scraping.append(base_url_wiki + full_name[0]+'_'+full_name[1])
        
    return links_to_scraping

# %% [markdown]
# ### ⚙️ Proceso

# %% [markdown]
# 👉 `En main_link se encuentra un listado con los nombres de los mejores programadores a los que quiero hacerle scraping (para no quemar los nombres ni los links)`

# %%
# Defino URLs base
main_link = "https://www.tutorialspoint.com/who-are-currently-the-best-programmers-in-the-world"
base_url_wiki = "https://es.wikipedia.org/wiki/"
print(main_link)
# Out:
# https://www.tutorialspoint.com/who-are-currently-the-best-programmers-in-the-world

# %%
# Genero las demas URLs
links_to_scraping = build_link_to_scraping(main_link, base_url_wiki)

# Hacer GET de cada URL con reintento
for link in links_to_scraping:
    try:
        call_wiki(link)
    except Exception as e:
        print("Error con la url: [{}]. Mensaje: {}. Inicia reintento en idioma Inglés.".format(link,e))
        call_wiki(link.replace("es.","en."))
        pass
# Out:
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Bill_Gates
# • Encabezado:
# 	 Bill Gates
# • Links 1er parrafo:
# 	Contenido => Seattle
# 	Titulo => Seattle
#
# 	Contenido => Washington
# 	Titulo => Washington (estado)
#
# 	Contenido => [1]
# 	Titulo => None
#
# 	Contenido => magnate empresarial
# 	Titulo => Magnate
#
# 	Contenido => informático
# 	Titulo => Informático
#
# 	Contenido => filántropo
# 	Titulo => Filantropía
#
# 	Contenido => [3]
# 	Titulo => None
#
# 	Contenido => estadounidense
# 	Titulo => Nacionalidad estadounidense
#
# 	Contenido => Microsoft
# 	Titulo => Microsoft
#
# 	Contenido => Paul Allen
# 	Titulo => Paul Allen
#
# 	Contenido => [4]
# 	Titulo => None
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/James_Gosling
# • Encabezado:
# 	 James Gosling
# • Links 1er parrafo:
# 	Contenido => OC
# 	Titulo => Orden de Canadá
#
# 	Contenido => 19 de mayo
# 	Titulo => 19 de mayo
#
# 	Contenido => 1955
# 	Titulo => 1955
#
# 	Contenido => Calgary
# 	Titulo => Calgary, Alberta
#
# 	Contenido => Alberta
# 	Titulo => Alberta
#
# 	Contenido => Canadá
# 	Titulo => Canadá
#
# 	Contenido => científico de la computación
# 	Titulo => Científico de la computación
#
# 	Contenido => lenguaje de programación Java
# 	Titulo => Lenguaje de programación Java
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Richard_Stallman
# • Encabezado:
# 	 Richard Stallman
# • Links 1er parrafo:
# 	Contenido => Manhattan
# 	Titulo => Manhattan
#
# 	Contenido => Nueva York
# 	Titulo => Nueva York
#
# 	Contenido => 16 de marzo
# 	Titulo => 16 de marzo
#
# 	Contenido => 1953
# 	Titulo => 1953
#
# 	Contenido => [1]
# 	Titulo => None
#
# 	Contenido => programador
# 	Titulo => Programador
#
# 	Contenido => estadounidense
# 	Titulo => Estados Unidos
#
# 	Contenido => movimiento del software libre
# 	Titulo => Movimiento del software libre
#
# 	Contenido => sistema operativo GNU
# 	Titulo => GNU
#
# 	Contenido => Free Software Foundation
# 	Titulo => Free Software Foundation
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Bjarne_Stroustrup
# • Encabezado:
# 	 Bjarne Stroustrup
# • Links 1er parrafo:
# 	Contenido => 30 de diciembre
# 	Titulo => 30 de diciembre
#
# 	Contenido => 1950
# 	Titulo => 1950
#
# 	Contenido => Aarhus
# 	Titulo => Aarhus
#
# 	Contenido => Dinamarca
# 	Titulo => Dinamarca
#
# 	Contenido => científico de la computación
# 	Titulo => Ciencias de la computación
#
# 	Contenido => Ciencias de la Computación
# 	Titulo => Ciencias de la Computación
#
# 	Contenido => Universidad A&M de Texas
# 	Titulo => Universidad A&M de Texas
#
# 	Contenido => C++
# 	Titulo => C++
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Tim_Berners-Lee
# • Encabezado:
# 	 Tim Berners-Lee
# • Links 1er parrafo:
# 	Contenido => Londres
# 	Titulo => Londres
#
# 	Contenido => Reino Unido
# 	Titulo => Reino Unido
#
# 	Contenido => 8 de junio
# 	Titulo => 8 de junio
#
# 	Contenido => 1955
# 	Titulo => 1955
#
# 	Contenido => científico de la computación
# 	Titulo => Científico de la computación
#
# 	Contenido => World Wide Web
# 	Titulo => World Wide Web
#
# 	Contenido => HTTP
# 	Titulo => HTTP
#
# 	Contenido => W3C
# 	Titulo => W3C
#
# 	Contenido => MIT
# 	Titulo => MIT
#
# 	Contenido => la Web
# 	Titulo => World Wide Web
#
# 	Contenido => Internet
# 	Titulo => Internet
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Ken_Thompson
# • Encabezado:
# 	 Ken Thompson
# • Links 1er parrafo:
# 	Contenido => Nueva Orleans
# 	Titulo => Nueva Orleans
#
# 	Contenido => Luisiana
# 	Titulo => Luisiana
#
# 	Contenido => 4 de febrero
# 	Titulo => 4 de febrero
#
# 	Contenido => 1943
# 	Titulo => 1943
#
# 	Contenido => ciencias de la computación
# 	Titulo => Ciencias de la computación
#
# 	Contenido => lenguaje de programación B
# 	Titulo => Lenguaje de programación B
#
# 	Contenido => sistema operativo
# 	Titulo => Sistema operativo
#
# 	Contenido => Plan 9
# 	Titulo => Plan 9 from Bell Labs
#
# 	Contenido => laboratorios Bell
# 	Titulo => Laboratorios Bell
#
# 	Contenido => Dennis Ritchie
# 	Titulo => Dennis Ritchie
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Linus_Torvalds
# • Encabezado:
# 	 Linus Torvalds
# • Links 1er parrafo:
# 	Contenido => Helsinki
# 	Titulo => Helsinki
#
# 	Contenido => Finlandia
# 	Titulo => Finlandia
#
# 	Contenido => [1]
# 	Titulo => None
#
# 	Contenido => ingeniero de software
# 	Titulo => Ingeniería de software
#
# 	Contenido => estadounidense
# 	Titulo => Nacionalidad estadounidense
#
# 	Contenido => [2]
# 	Titulo => None
#
# 	Contenido => kernel
# 	Titulo => Núcleo (informática)
#
# 	Contenido => núcleo
# 	Titulo => Núcleo (informática)
#
# 	Contenido => Linux
# 	Titulo => Linux (núcleo)
#
# 	Contenido => sistema operativo
# 	Titulo => Sistema operativo
#
# 	Contenido => Minix
# 	Titulo => Minix
#
# 	Contenido => Andrew S. Tanenbaum
# 	Titulo => Andrew S. Tanenbaum
#
# 	Contenido => compiladores
# 	Titulo => Compilador
#
# 	Contenido => proyecto GNU
# 	Titulo => Proyecto GNU
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Dennis_Ritchie
# • Encabezado:
# 	 Dennis Ritchie
# • Links 1er parrafo:
# 	Contenido => 9 de septiembre
# 	Titulo => 9 de septiembre
#
# 	Contenido => 1941
# 	Titulo => 1941
#
# 	Contenido => 12 de octubre
# 	Titulo => 12 de octubre
#
# 	Contenido => 2011
# 	Titulo => 2011
#
# 	Contenido => científico de la computación
# 	Titulo => Ciencias de la computación
#
# 	Contenido => estadounidense
# 	Titulo => Estados Unidos
#
# 	Contenido => [1]
# 	Titulo => None
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Jack_Dorsey
# • Encabezado:
# 	 Jack Dorsey
# • Links 1er parrafo:
# 	Contenido => [2]
# 	Titulo => None
#
# 	Contenido => San Luis
# 	Titulo => San Luis (Misuri)
#
# 	Contenido => Misuri
# 	Titulo => Misuri
#
# 	Contenido => 19 de noviembre
# 	Titulo => 19 de noviembre
#
# 	Contenido => 1976
# 	Titulo => 1976
#
# 	Contenido => estadounidense
# 	Titulo => Estados Unidos
#
# 	Contenido => Twitter
# 	Titulo => Twitter
#
# 	Contenido => [3]
# 	Titulo => None
#
# 	Contenido => Square
# 	Titulo => Square (servicio de pago) (aún no redactado)
#
# 	Contenido => [4]
# 	Titulo => None
#
# 	Contenido => [5]
# 	Titulo => None
#
# Error con la url: [https://es.wikipedia.org/wiki/Ruchi_Sanghvi]. Mensaje: HTTP Error 404: Not Found. Inicia reintento en idioma Inglés.
# ====================================================================================================
# • Url:
# 	 https://en.wikipedia.org/wiki/Ruchi_Sanghvi
# • Encabezado:
# 	 Ruchi Sanghvi
# • Links 1er parrafo:
# 	Contenido => [1]
# 	Titulo => None
#
# 	Contenido => [2]
# 	Titulo => None
#
# 	Contenido => engineer
# 	Titulo => Computer engineering
#
# 	Contenido => Facebook
# 	Titulo => Facebook
#
# 	Contenido => [3]
# 	Titulo => None
#
# 	Contenido => [4]
# 	Titulo => None
#
# 	Contenido => [5]
# 	Titulo => None
#
# 	Contenido => Dropbox
# 	Titulo => Dropbox (service)
#
# 	Contenido => Dropbox
# 	Titulo => Dropbox (service)
#
# 	Contenido => [6]
# 	Titulo => None
#
# 	Contenido => [7]
# 	Titulo => None
#
# Error con la url: [https://es.wikipedia.org/wiki/Drew_Houston]. Mensaje: HTTP Error 404: Not Found. Inicia reintento en idioma Inglés.
# ====================================================================================================
# • Url:
# 	 https://en.wikipedia.org/wiki/Drew_Houston
# • Encabezado:
# 	 Drew Houston
# • Links 1er parrafo:
# 	Contenido => /ˈhaʊs.tən/
# 	Titulo => Help:IPA/English
#
# 	Contenido => Dropbox
# 	Titulo => Dropbox (service)
#
# 	Contenido => Forbes
# 	Titulo => Forbes
#
# 	Contenido => [1]
# 	Titulo => None
#
# 	Contenido => [2]
# 	Titulo => None
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Mark_Zuckerberg
# • Encabezado:
# 	 Mark Zuckerberg
# • Links 1er parrafo:
# 	Contenido => White Plains
# 	Titulo => White Plains (Nueva York)
#
# 	Contenido => Estados Unidos
# 	Titulo => Estados Unidos
#
# 	Contenido => 14 de mayo
# 	Titulo => 14 de mayo
#
# 	Contenido => 1984
# 	Titulo => 1984
#
# 	Contenido => programador
# 	Titulo => Programador
#
# 	Contenido => empresario
# 	Titulo => Empresario
#
# 	Contenido => estadounidense
# 	Titulo => Nacionalidad estadounidense
#
# 	Contenido => Facebook
# 	Titulo => Facebook
#
# 	Contenido => Universidad de Harvard
# 	Titulo => Universidad de Harvard
#
# 	Contenido => ciencias de la computación
# 	Titulo => Ciencias de la computación
#
# 	Contenido => Eduardo Saverin
# 	Titulo => Eduardo Saverin
#
# 	Contenido => Dustin Moskovitz
# 	Titulo => Dustin Moskovitz
#
# 	Contenido => Chris Hughes
# 	Titulo => Chris Hughes
#
# 	Contenido => 2018
# 	Titulo => 2018
#
# 	Contenido => lista de multimillonarios
# 	Titulo => Anexo:Multimillonarios según Forbes
#
# 	Contenido => Forbes
# 	Titulo => Forbes
#
# 	Contenido => millones de dólares
# 	Titulo => Dólar estadounidense
#
# 	Contenido => [1]
# 	Titulo => None
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Larry_Wall
# • Encabezado:
# 	 Larry Wall
# • Links 1er parrafo:
# 	Contenido => Los Ángeles
# 	Titulo => Los Ángeles
#
# 	Contenido => programador
# 	Titulo => Programador
#
# 	Contenido => escritor
# 	Titulo => Escritor
#
# 	Contenido => lenguaje de programación
# 	Titulo => Lenguaje de programación
#
# 	Contenido => Perl
# 	Titulo => Perl
#
# 	Contenido => 1987
# 	Titulo => 1987
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Yukihiro_Matsumoto
# • Encabezado:
# 	 Yukihiro Matsumoto
# • Links 1er parrafo:
# 	Contenido => 14 de abril
# 	Titulo => 14 de abril
#
# 	Contenido => 1965
# 	Titulo => 1965
#
# 	Contenido => informático
# 	Titulo => Informático
#
# 	Contenido => programador
# 	Titulo => Programador
#
# 	Contenido => software libre
# 	Titulo => Software libre
#
# 	Contenido => lenguaje de programación
# 	Titulo => Lenguaje de programación
#
# 	Contenido => Ruby
# 	Titulo => Ruby
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/John_Resig
# • Encabezado:
# 	 John Resig
# • Links 1er parrafo:
# 	Contenido => programador
# 	Titulo => Programador
#
# 	Contenido => Fundación Mozilla
# 	Titulo => Fundación Mozilla
#
# 	Contenido => biblioteca
# 	Titulo => Biblioteca (informática)
#
# 	Contenido => JavaScript
# 	Titulo => JavaScript
#
# 	Contenido => jQuery
# 	Titulo => JQuery
#
# 	Contenido => blogs
# 	Titulo => Blog
#
# 	Contenido => [1]
# 	Titulo => None
#
# ====================================================================================================
# • Url:
# 	 https://es.wikipedia.org/wiki/Phil_Katz
# • Encabezado:
# 	 Phil Katz
# • Links 1er parrafo:
# 	Contenido => 3 de noviembre
# 	Titulo => 3 de noviembre
#
# 	Contenido => 1962
# 	Titulo => 1962
#
# 	Contenido => 14 de abril
# 	Titulo => 14 de abril
#
# 	Contenido => 2000
# 	Titulo => 2000
#
# 	Contenido => ZIP
# 	Titulo => ZIP
#
# 	Contenido => PKZIP
# 	Titulo => PKZIP (aún no redactado)
